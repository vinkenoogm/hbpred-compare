# %% [markdown]
# # Preprocessing of raw blood donation data for use in SVMs - Finnish data

# %% [markdown]
# ### Importing packages

# %%
import numpy as np
import pandas as pd 
import datetime
import ast
import pickle
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Loading original data files
# 'vdonationc' contains all donation visits but information on genetic markers is present only in 'lastdon' so we will merge them.

# %%
data_last = pd.read_csv('../../data/lastdon.csv', low_memory=False)
data_all = pd.read_csv('../../data/vdonationc.csv', low_memory=False)
data_raw = data_all.merge(data_last[['vdonor', 'height', 'weight', 'smoking', 'bmi', 
                                     'snp_17_58358769', 'snp_6_32617727', 'snp_15_45095352',
                                     'snp_1_169549811', 'prs_anemia', 'prs_ferritin', 'prs_hemoglobin']], 
                          how='inner',
                          on='vdonor')
print(data_all.shape, data_raw.shape)

# %%
data_raw.columns

# %% [markdown]
# Out of 5 786 320 total donations in vdonationc, we have genetic markers for 645 978.
#
# ### Selecting variables and relevant visits
# Drop some columns that are not needed: zip code, city, donation site and blood group. Blood group might be interesting to include, but factors have to be dummy-coded for SVMs. For now, drop it. Only keep successful whole-blood donations (donat_phleb == 'K') and Hb-deferred ones (Hb_deferral == 1 & donat_phleb == '\*') from the past 5 years (2016-2020).

# %%
data = data_raw.copy().drop(columns=['Unnamed: 0', 'zip', 'city', 'site', 'aborh'])
data['date'] = pd.to_datetime(data['date'])
data['year'] = data['date'].dt.year
data['month'] = data['date'].dt.month
data = data.loc[(data.donat_phleb == 'K') | ((data.donat_phleb == '*') & (data.Hb_deferral == 1)), ]
print(data_raw.shape, data.shape)

data = data.drop(columns=['status','donat_phleb'])
#data.to_pickle('../../data/alldata.pkl')

data = data.loc[data.year > 2015, ]
#data.to_pickle('../../data/alldata_2016_2020.pkl')
print(data.shape)

# %% [markdown]
# This leaves us with 201 843 donation attempts.
#
# Add variables HbPrevn and DaystoPrevn for n between 1-5.

# %%
def add_prev_hb_time(df, number):
    colnames = ['HbPrev'+str(number), 'DaystoPrev'+str(number)]
    df[colnames[0]] = df['Hb'].shift(number)
    df[colnames[1]] = (df['date'] - df['date'].shift(number)) / pd.Timedelta('1 day') 
    return df

data = data.dropna(axis=0)

df_1 = data.groupby('vdonor').apply(add_prev_hb_time, number=1)
print(datetime.datetime.now(), '1 done')
df_2 = df_1.groupby('vdonor').apply(add_prev_hb_time, number=2)
print(datetime.datetime.now(), '2 done')
df_3 = df_2.groupby('vdonor').apply(add_prev_hb_time, number=3)
print(datetime.datetime.now(), '3 done')
df_4 = df_3.groupby('vdonor').apply(add_prev_hb_time, number=4)
print(datetime.datetime.now(), '4 done')
df_5 = df_4.groupby('vdonor').apply(add_prev_hb_time, number=5)
print(datetime.datetime.now(), '5 done')
df_5.head()

df_5.to_pickle('../../data/df_2016_2020.pkl')

# %% [markdown]
# ### Checking pre-processed data

# %%
df = pd.read_pickle('../../data/df_2016_2020.pkl')
df.describe()

# %% [markdown]
# Min, max and mean for most variables look sensible. However the minimum value for several DaystoPrevn variables is very low, so we investigate this. From the Veripalvelu website: *The minimum interval between blood donations is 91 days for women and 61 days for men.* Values smaller than this can occur if the previous visit was a deferral, however. This is the case for almost all these observations. There are a few (<100) observations that have DaystoPrevn variables smaller than the minimum donation interval, but they do appear to be valid donations. We leave them in the dataset.
#
# A look at the distribution of number of donation attempts per donor:

# %%
dcounts = df.vdonor.value_counts()

plt.hist(dcounts)
plt.show()

# %% [markdown]
# # Marginal distributions of variables per SVM
#
# We want to describe the distributions of all variables in the data set separately for women and men, and separately for the five models SVM-1 through SVM-5.

# %%
df = pd.read_pickle('../../data/df_2016_2020.pkl')
df['prs_anemia'] = df['prs_anemia'].round(10)
df['prs_ferritin'] = df['prs_ferritin'].round(10)
df['prs_hemoglobin'] = df['prs_hemoglobin'].round(10)

# %%
df.head()
# Out:
#           vdonor  age    sex       date     Hb  Hb_deferral  height  weight  \
# 49  MV4ALL7LH8X3   52  Women 2016-03-31  131.0            0     163      79
# 50  MV4ALL7LH8X3   52  Women 2016-07-05  118.0            1     163      79
# 51  MV4ALL7LH8X3   52  Women 2016-10-06  125.0            0     163      79
# 52  MV4ALL7LH8X3   53  Women 2016-12-30  121.0            1     163      79
# 53  MV4ALL7LH8X3   53  Women 2017-03-23  138.0            0     163      79
#
#     smoking      bmi  snp_17_58358769  snp_6_32617727  snp_15_45095352  \
# 49    False  29.7339                0               1                0
# 50    False  29.7339                0               1                0
# 51    False  29.7339                0               1                0
# 52    False  29.7339                0               1                0
# 53    False  29.7339                0               1                0
#
#     snp_1_169549811  prs_anemia  prs_ferritin  prs_hemoglobin  year  month  \
# 49                0    0.000001 -1.510000e-08       -0.000002  2016      3
# 50                0    0.000001 -1.510000e-08       -0.000002  2016      7
# 51                0    0.000001 -1.510000e-08       -0.000002  2016     10
# 52                0    0.000001 -1.510000e-08       -0.000002  2016     12
# 53                0    0.000001 -1.510000e-08       -0.000002  2017      3
#
#     HbPrev1  DaystoPrev1  HbPrev2  DaystoPrev2  HbPrev3  DaystoPrev3  HbPrev4  \
# 49      NaN          NaN      NaN          NaN      NaN          NaN      NaN
# 50    131.0         96.0      NaN          NaN      NaN          NaN      NaN
# 51    118.0         93.0    131.0        189.0      NaN          NaN      NaN
# 52    125.0         85.0    118.0        178.0    131.0        274.0      NaN
# 53    121.0         83.0    125.0        168.0    118.0        261.0    131.0
#
#     DaystoPrev4  HbPrev5  DaystoPrev5
# 49          NaN      NaN          NaN
# 50          NaN      NaN          NaN
# 51          NaN      NaN          NaN
# 52          NaN      NaN          NaN
# 53        357.0      NaN          NaN

# %%
def describe_numerical(x):
    xmin, xq1, xmedian, xq3, xmax = np.percentile(x, [0, 25, 50, 75, 100]) 
    return(xmin, xq1, xmedian, xq3, xmax)

def describe_categorical(x):
    xoccs = x.value_counts(sort=False)
    xoccsn = x.value_counts(normalize=True, sort=False)
#    df = pd.DataFrame({'Value':xoccs.index,
#                       'Count':xoccs.values,
#                       'Proportion': xoccsn.values})
    return(xoccs.index, xoccs.values, xoccsn.values)

def describe_df(df):
    xcount = df.shape[1]
    # numerical variables
    df_num = df.drop(columns=['year', 'smoking', 'snp_17_58358769', 'snp_6_32617727', 'snp_15_45095352', 'snp_1_169549811'])
    res_num = df_num.apply(describe_numerical, axis='index').transpose()
    res_num.columns = ['minimum', 'Q1', 'median', 'Q3', 'maximum']
    # categorical variables
    res_cat = []
    for variable in ['year', 'smoking', 'snp_17_58358769', 'snp_6_32617727', 'snp_15_45095352', 'snp_1_169549811']:
        res = describe_categorical(df[variable])
        res = pd.DataFrame(res).transpose()
        res.columns = ['Value','Count','Proportion']
        res_cat.append(res)
    return(res_num, res_cat)

# %% [markdown]
# ### Male donors

# %%
df_m = df.loc[df['sex'] == 'Men', ['year', 'age', 'month', 'smoking', 'height', 'weight', 'bmi',
                         'snp_17_58358769', 'snp_6_32617727', 'snp_15_45095352', 'snp_1_169549811', 'prs_anemia', 'prs_ferritin',
                         'prs_hemoglobin', 'HbPrev1', 'DaystoPrev1', 'HbPrev2', 'DaystoPrev2','HbPrev3', 'DaystoPrev3',
                         'HbPrev4', 'DaystoPrev4', 'HbPrev5', 'DaystoPrev5']]

for nback in range(1, 6):
    varname = 'HbPrev' + str(nback)
    df_sub = df_m.dropna(subset=['HbPrev'+str(nback)])
    print(nback, 'donations back')
    res_num, res_cat = describe_df(df_sub)
    print('Numerical variables:')
    display(res_num)
    for i, varname in enumerate(['year', 'smoking', 'snp_17_58358769', 'snp_6_32617727', 'snp_15_45095352', 'snp_1_169549811']):
        print('Variable', varname)
        display(res_cat[i])
# Out:
# 1 donations back
# Numerical variables:
#                    minimum            Q1        median            Q3  \
# age              18.000000  3.800000e+01  5.200000e+01  6.000000e+01
# month             1.000000  3.000000e+00  6.000000e+00  1.000000e+01
# height          149.000000  1.750000e+02  1.800000e+02  1.840000e+02
# weight           50.000000  7.800000e+01  8.600000e+01  9.600000e+01
# bmi              15.319690  2.456931e+01  2.670362e+01  2.942508e+01
# prs_anemia       -0.000004 -8.773000e-07 -3.880000e-08  7.920000e-07
# prs_ferritin     -0.000007 -1.271712e-06 -2.347990e-08  1.241847e-06
# prs_hemoglobin   -0.000017 -3.095667e-06  1.816460e-08  3.254924e-06
# HbPrev1         102.000000  1.470000e+02  1.540000e+02  1.610000e+02
# DaystoPrev1       1.000000  7.100000e+01  9.800000e+01  1.470000e+02
# HbPrev2                NaN           NaN           NaN           NaN
# DaystoPrev2            NaN           NaN           NaN           NaN
# HbPrev3                NaN           NaN           NaN           NaN
# DaystoPrev3            NaN           NaN           NaN           NaN
# HbPrev4                NaN           NaN           NaN           NaN
# DaystoPrev4            NaN           NaN           NaN           NaN
# HbPrev5                NaN           NaN           NaN           NaN
# DaystoPrev5            NaN           NaN           NaN           NaN
#
#                     maximum
# age               71.000000
# month             12.000000
# height           210.000000
# weight           190.000000
# bmi               65.192744
# prs_anemia         0.000005
# prs_ferritin       0.000008
# prs_hemoglobin     0.000016
# HbPrev1          196.000000
# DaystoPrev1     1212.000000
# HbPrev2                 NaN
# DaystoPrev2             NaN
# HbPrev3                 NaN
# DaystoPrev3             NaN
# HbPrev4                 NaN
# DaystoPrev4             NaN
# HbPrev5                 NaN
# DaystoPrev5             NaN
# Variable year
#     Value    Count  Proportion
# 0  2017.0  21036.0    0.235497
# 1  2018.0  24767.0    0.277265
# 2  2019.0  24552.0    0.274858
# 3  2016.0  12425.0    0.139097
# 4  2020.0   6546.0    0.073282
# Variable smoking
#    Value  Count Proportion
# 0  False  79866   0.894096
# 1   True   9460   0.105904
# Variable snp_17_58358769
#    Value    Count  Proportion
# 0    0.0  87791.0    0.982816
# 1    1.0   1535.0    0.017184
# Variable snp_6_32617727
#    Value    Count  Proportion
# 0    1.0  43927.0    0.491761
# 1    2.0  18489.0    0.206983
# 2    0.0  26910.0    0.301256
# Variable snp_15_45095352
#    Value    Count  Proportion
# 0    0.0  78603.0    0.879957
# 1    1.0  10233.0    0.114558
# 2    2.0    490.0    0.005486
# Variable snp_1_169549811
#    Value    Count  Proportion
# 0    0.0  85788.0    0.960392
# 1    1.0   3503.0    0.039216
# 2    2.0     35.0    0.000392
# 2 donations back
# Numerical variables:
#                    minimum            Q1        median            Q3  \
# age              18.000000  4.000000e+01  5.200000e+01  6.000000e+01
# month             1.000000  3.000000e+00  7.000000e+00  1.000000e+01
# height          149.000000  1.750000e+02  1.800000e+02  1.840000e+02
# weight           50.000000  7.800000e+01  8.600000e+01  9.600000e+01
# bmi              15.319690  2.457787e+01  2.672993e+01  2.953099e+01
# prs_anemia       -0.000004 -8.791000e-07 -4.110000e-08  7.896500e-07
# prs_ferritin     -0.000007 -1.270993e-06 -2.210532e-08  1.250257e-06
# prs_hemoglobin   -0.000016 -3.088784e-06  2.288800e-08  3.275019e-06
# HbPrev1         102.000000  1.470000e+02  1.540000e+02  1.610000e+02
# DaystoPrev1       1.000000  7.000000e+01  9.700000e+01  1.390000e+02
# HbPrev2         102.000000  1.470000e+02  1.540000e+02  1.610000e+02
# DaystoPrev2      59.000000  1.540000e+02  2.040000e+02  2.930000e+02
# HbPrev3                NaN           NaN           NaN           NaN
# DaystoPrev3            NaN           NaN           NaN           NaN
# HbPrev4                NaN           NaN           NaN           NaN
# DaystoPrev4            NaN           NaN           NaN           NaN
# HbPrev5                NaN           NaN           NaN           NaN
# DaystoPrev5            NaN           NaN           NaN           NaN
#
#                     maximum
# age               71.000000
# month             12.000000
# height           210.000000
# weight           187.000000
# bmi               65.192744
# prs_anemia         0.000005
# prs_ferritin       0.000008
# prs_hemoglobin     0.000016
# HbPrev1          195.000000
# DaystoPrev1     1199.000000
# HbPrev2          196.000000
# DaystoPrev2     1521.000000
# HbPrev3                 NaN
# DaystoPrev3             NaN
# HbPrev4                 NaN
# DaystoPrev4             NaN
# HbPrev5                 NaN
# DaystoPrev5             NaN
# Variable year
#     Value    Count  Proportion
# 0  2018.0  22981.0    0.293118
# 1  2019.0  23638.0    0.301497
# 2  2017.0  18597.0    0.237201
# 3  2016.0   6691.0    0.085342
# 4  2020.0   6495.0    0.082842
# Variable smoking
#    Value  Count Proportion
# 0  False  70199   0.895373
# 1   True   8203   0.104627
# Variable snp_17_58358769
#    Value    Count  Proportion
# 0    0.0  77094.0    0.983317
# 1    1.0   1308.0    0.016683
# Variable snp_6_32617727
#    Value    Count  Proportion
# 0    1.0  38564.0    0.491875
# 1    2.0  16216.0    0.206831
# 2    0.0  23622.0    0.301293
# Variable snp_15_45095352
#    Value    Count  Proportion
# 0    0.0  69065.0    0.880909
# 1    1.0   8906.0    0.113594
# 2    2.0    431.0    0.005497
# Variable snp_1_169549811
#    Value    Count  Proportion
# 0    0.0  75280.0    0.960180
# 1    1.0   3092.0    0.039438
# 2    2.0     30.0    0.000383
# 3 donations back
# Numerical variables:
#                    minimum            Q1        median            Q3  \
# age              18.000000  4.100000e+01  5.300000e+01  6.100000e+01
# month             1.000000  3.000000e+00  6.000000e+00  1.000000e+01
# height          149.000000  1.750000e+02  1.800000e+02  1.840000e+02
# weight           50.000000  7.800000e+01  8.600000e+01  9.600000e+01
# bmi              16.706205  2.461521e+01  2.676978e+01  2.953686e+01
# prs_anemia       -0.000004 -8.825000e-07 -4.690000e-08  7.872000e-07
# prs_ferritin     -0.000007 -1.265253e-06 -1.786850e-08  1.260020e-06
# prs_hemoglobin   -0.000016 -3.081072e-06  4.249170e-08  3.295483e-06
# HbPrev1         102.000000  1.470000e+02  1.540000e+02  1.610000e+02
# DaystoPrev1       1.000000  7.000000e+01  9.400000e+01  1.320000e+02
# HbPrev2         102.000000  1.460000e+02  1.540000e+02  1.610000e+02
# DaystoPrev2      59.000000  1.520000e+02  1.970000e+02  2.740000e+02
# HbPrev3         102.000000  1.460000e+02  1.540000e+02  1.610000e+02
# DaystoPrev3      91.000000  2.350000e+02  3.060000e+02  4.200000e+02
# HbPrev4                NaN           NaN           NaN           NaN
# DaystoPrev4            NaN           NaN           NaN           NaN
# HbPrev5                NaN           NaN           NaN           NaN
# DaystoPrev5            NaN           NaN           NaN           NaN
#
#                     maximum
# age               71.000000
# month             12.000000
# height           210.000000
# weight           187.000000
# bmi               65.192744
# prs_anemia         0.000005
# prs_ferritin       0.000008
# prs_hemoglobin     0.000016
# HbPrev1          195.000000
# DaystoPrev1      945.000000
# HbPrev2          195.000000
# DaystoPrev2     1379.000000
# HbPrev3          195.000000
# DaystoPrev3     1569.000000
# HbPrev4                 NaN
# DaystoPrev4             NaN
# HbPrev5                 NaN
# DaystoPrev5             NaN
# Variable year
#     Value    Count  Proportion
# 0  2019.0  22433.0    0.328559
# 1  2018.0  21024.0    0.307922
# 2  2016.0   2973.0    0.043543
# 3  2017.0  15486.0    0.226811
# 4  2020.0   6361.0    0.093165
# Variable smoking
#    Value  Count Proportion
# 0  False  61187   0.896158
# 1   True   7090   0.103842
# Variable snp_17_58358769
#    Value    Count  Proportion
# 0    0.0  67174.0    0.983845
# 1    1.0   1103.0    0.016155
# Variable snp_6_32617727
#    Value    Count  Proportion
# 0    1.0  33599.0    0.492098
# 1    2.0  14104.0    0.206570
# 2    0.0  20574.0    0.301331
# Variable snp_15_45095352
#    Value    Count  Proportion
# 0    0.0  60224.0    0.882054
# 1    1.0   7675.0    0.112410
# 2    2.0    378.0    0.005536
# Variable snp_1_169549811
#    Value    Count  Proportion
# 0    0.0  65543.0    0.959957
# 1    1.0   2708.0    0.039662
# 2    2.0     26.0    0.000381
# 4 donations back
# Numerical variables:
#                    minimum            Q1        median            Q3  \
# age              18.000000  4.200000e+01  5.400000e+01  6.100000e+01
# month             1.000000  3.000000e+00  6.000000e+00  1.000000e+01
# height          149.000000  1.750000e+02  1.800000e+02  1.840000e+02
# weight           50.000000  7.800000e+01  8.600000e+01  9.600000e+01
# bmi              16.706205  2.461810e+01  2.677551e+01  2.956195e+01
# prs_anemia       -0.000004 -8.832000e-07 -5.210000e-08  7.826000e-07
# prs_ferritin     -0.000006 -1.259050e-06 -9.804800e-09  1.264376e-06
# prs_hemoglobin   -0.000016 -3.074471e-06  5.436680e-08  3.329030e-06
# HbPrev1         102.000000  1.470000e+02  1.540000e+02  1.610000e+02
# DaystoPrev1       1.000000  6.900000e+01  9.200000e+01  1.260000e+02
# HbPrev2         102.000000  1.470000e+02  1.540000e+02  1.610000e+02
# DaystoPrev2      59.000000  1.470000e+02  1.910000e+02  2.600000e+02
# HbPrev3         112.000000  1.460000e+02  1.530000e+02  1.610000e+02
# DaystoPrev3      91.000000  2.310000e+02  2.940000e+02  3.930000e+02
# HbPrev4         102.000000  1.460000e+02  1.530000e+02  1.610000e+02
# DaystoPrev4     153.000000  3.140000e+02  3.990000e+02  5.350000e+02
# HbPrev5                NaN           NaN           NaN           NaN
# DaystoPrev5            NaN           NaN           NaN           NaN
#
#                     maximum
# age               71.000000
# month             12.000000
# height           210.000000
# weight           187.000000
# bmi               65.192744
# prs_anemia         0.000005
# prs_ferritin       0.000008
# prs_hemoglobin     0.000016
# HbPrev1          195.000000
# DaystoPrev1      848.000000
# HbPrev2          195.000000
# DaystoPrev2     1322.000000
# HbPrev3          195.000000
# DaystoPrev3     1421.000000
# HbPrev4          195.000000
# DaystoPrev4     1545.000000
# HbPrev5                 NaN
# DaystoPrev5             NaN
# Variable year
#     Value    Count  Proportion
# 0  2018.0  18891.0    0.320300
# 1  2019.0  21014.0    0.356296
# 2  2017.0  11927.0    0.202225
# 3  2020.0   6144.0    0.104173
# 4  2016.0   1003.0    0.017006
# Variable smoking
#    Value  Count Proportion
# 0   True   6083   0.103138
# 1  False  52896   0.896862
# Variable snp_17_58358769
#    Value    Count  Proportion
# 0    0.0  58062.0    0.984452
# 1    1.0    917.0    0.015548
# Variable snp_6_32617727
#    Value    Count  Proportion
# 0    2.0  12183.0    0.206565
# 1    1.0  29014.0    0.491938
# 2    0.0  17782.0    0.301497
# Variable snp_15_45095352
#    Value    Count  Proportion
# 0    0.0  52094.0    0.883264
# 1    1.0   6557.0    0.111175
# 2    2.0    328.0    0.005561
# Variable snp_1_169549811
#    Value    Count  Proportion
# 0    1.0   2345.0    0.039760
# 1    0.0  56612.0    0.959867
# 2    2.0     22.0    0.000373
# 5 donations back
# Numerical variables:
#                    minimum            Q1        median            Q3  \
# age              18.000000  4.300000e+01  5.400000e+01  6.200000e+01
# month             1.000000  3.000000e+00  6.000000e+00  1.000000e+01
# height          149.000000  1.750000e+02  1.800000e+02  1.840000e+02
# weight           50.000000  7.800000e+01  8.600000e+01  9.600000e+01
# bmi              16.706205  2.461810e+01  2.679494e+01  2.958580e+01
# prs_anemia       -0.000004 -8.842000e-07 -5.590000e-08  7.818000e-07
# prs_ferritin     -0.000006 -1.255091e-06 -4.677100e-09  1.273029e-06
# prs_hemoglobin   -0.000016 -3.067383e-06  7.294040e-08  3.349797e-06
# HbPrev1         102.000000  1.470000e+02  1.540000e+02  1.610000e+02
# DaystoPrev1       1.000000  6.800000e+01  9.000000e+01  1.190000e+02
# HbPrev2         102.000000  1.470000e+02  1.540000e+02  1.610000e+02
# DaystoPrev2      59.000000  1.460000e+02  1.860000e+02  2.480000e+02
# HbPrev3         112.000000  1.460000e+02  1.530000e+02  1.610000e+02
# DaystoPrev3      91.000000  2.250000e+02  2.860000e+02  3.740000e+02
# HbPrev4         112.000000  1.460000e+02  1.530000e+02  1.610000e+02
# DaystoPrev4     153.000000  3.070000e+02  3.850000e+02  5.040000e+02
# HbPrev5         102.000000  1.460000e+02  1.530000e+02  1.610000e+02
# DaystoPrev5     224.000000  3.890000e+02  4.890000e+02  6.390000e+02
#
#                     maximum
# age               71.000000
# month             12.000000
# height           210.000000
# weight           187.000000
# bmi               65.192744
# prs_anemia         0.000005
# prs_ferritin       0.000008
# prs_hemoglobin     0.000016
# HbPrev1          195.000000
# DaystoPrev1      833.000000
# HbPrev2          195.000000
# DaystoPrev2     1099.000000
# HbPrev3          195.000000
# DaystoPrev3     1218.000000
# HbPrev4          195.000000
# DaystoPrev4     1402.000000
# HbPrev5          195.000000
# DaystoPrev5     1535.000000
# Variable year
#     Value    Count  Proportion
# 0  2018.0  16612.0    0.328554
# 1  2019.0  19434.0    0.384367
# 2  2017.0   8468.0    0.167481
# 3  2020.0   5875.0    0.116196
# 4  2016.0    172.0    0.003402
# Variable smoking
#    Value  Count Proportion
# 0   True   5180   0.102451
# 1  False  45381   0.897549
# Variable snp_17_58358769
#    Value    Count  Proportion
# 0    0.0  49810.0    0.985147
# 1    1.0    751.0    0.014853
# Variable snp_6_32617727
#    Value    Count  Proportion
# 0    2.0  10455.0    0.206780
# 1    1.0  24855.0    0.491584
# 2    0.0  15251.0    0.301636
# Variable snp_15_45095352
#    Value    Count  Proportion
# 0    0.0  44723.0    0.884536
# 1    1.0   5556.0    0.109887
# 2    2.0    282.0    0.005577
# Variable snp_1_169549811
#    Value    Count  Proportion
# 0    1.0   2016.0    0.039873
# 1    0.0  48526.0    0.959752
# 2    2.0     19.0    0.000376

# %% [markdown]
# ### Female donors

# %%
df_f = df.loc[df['sex'] == 'Women', ['year', 'age', 'month', 'smoking', 'height', 'weight', 'bmi',
                         'snp_17_58358769', 'snp_6_32617727', 'snp_15_45095352', 'snp_1_169549811', 'prs_anemia', 'prs_ferritin',
                         'prs_hemoglobin', 'HbPrev1', 'DaystoPrev1', 'HbPrev2', 'DaystoPrev2','HbPrev3', 'DaystoPrev3',
                         'HbPrev4', 'DaystoPrev4', 'HbPrev5', 'DaystoPrev5']]

for nback in range(1, 6):
    varname = 'HbPrev' + str(nback)
    df_sub = df_f.dropna(subset=['HbPrev'+str(nback)])
    print(nback, 'donations back')
    res_num, res_cat = describe_df(df_sub)
    print('Numerical variables:')
    display(res_num)
    for i, varname in enumerate(['year', 'smoking', 'snp_17_58358769', 'snp_6_32617727', 'snp_15_45095352', 'snp_1_169549811']):
        print('Variable', varname)
        display(res_cat[i])
# Out:
# 1 donations back
# Numerical variables:
#                    minimum            Q1        median            Q3  \
# age              18.000000  2.900000e+01  4.600000e+01  5.700000e+01
# month             1.000000  3.000000e+00  6.000000e+00  1.000000e+01
# height          138.000000  1.620000e+02  1.660000e+02  1.700000e+02
# weight           49.000000  6.400000e+01  7.100000e+01  8.200000e+01
# bmi              15.942183  2.318367e+01  2.578125e+01  2.939469e+01
# prs_anemia       -0.000005 -8.472577e-07 -2.266920e-09  8.279037e-07
# prs_ferritin     -0.000007 -1.193138e-06  3.224310e-08  1.279313e-06
# prs_hemoglobin   -0.000016 -3.010211e-06  3.850150e-08  3.105051e-06
# HbPrev1          86.000000  1.330000e+02  1.400000e+02  1.470000e+02
# DaystoPrev1       2.000000  1.040000e+02  1.320000e+02  2.060000e+02
# HbPrev2                NaN           NaN           NaN           NaN
# DaystoPrev2            NaN           NaN           NaN           NaN
# HbPrev3                NaN           NaN           NaN           NaN
# DaystoPrev3            NaN           NaN           NaN           NaN
# HbPrev4                NaN           NaN           NaN           NaN
# DaystoPrev4            NaN           NaN           NaN           NaN
# HbPrev5                NaN           NaN           NaN           NaN
# DaystoPrev5            NaN           NaN           NaN           NaN
#
#                     maximum
# age               70.000000
# month             12.000000
# height           198.000000
# weight           172.000000
# bmi               64.776711
# prs_anemia         0.000005
# prs_ferritin       0.000008
# prs_hemoglobin     0.000018
# HbPrev1          187.000000
# DaystoPrev1     1421.000000
# HbPrev2                 NaN
# DaystoPrev2             NaN
# HbPrev3                 NaN
# DaystoPrev3             NaN
# HbPrev4                 NaN
# DaystoPrev4             NaN
# HbPrev5                 NaN
# DaystoPrev5             NaN
# Variable year
#     Value    Count  Proportion
# 0  2016.0   9249.0    0.109488
# 1  2017.0  19230.0    0.227641
# 2  2018.0  24973.0    0.295626
# 3  2019.0  24768.0    0.293199
# 4  2020.0   6255.0    0.074046
# Variable smoking
#    Value  Count Proportion
# 0  False  74317   0.879751
# 1   True  10158   0.120249
# Variable snp_17_58358769
#    Value    Count  Proportion
# 0    0.0  83166.0    0.984504
# 1    1.0   1303.0    0.015425
# 2    2.0      6.0    0.000071
# Variable snp_6_32617727
#    Value    Count  Proportion
# 0    1.0  41700.0    0.493637
# 1    0.0  26483.0    0.313501
# 2    2.0  16292.0    0.192862
# Variable snp_15_45095352
#    Value    Count  Proportion
# 0    0.0  73884.0    0.874626
# 1    1.0  10218.0    0.120959
# 2    2.0    373.0    0.004416
# Variable snp_1_169549811
#    Value    Count  Proportion
# 0    0.0  80802.0    0.956520
# 1    1.0   3603.0    0.042652
# 2    2.0     70.0    0.000829
# 2 donations back
# Numerical variables:
#                    minimum            Q1        median            Q3  \
# age              18.000000  3.000000e+01  4.700000e+01  5.800000e+01
# month             1.000000  3.000000e+00  6.000000e+00  1.000000e+01
# height          138.000000  1.620000e+02  1.660000e+02  1.700000e+02
# weight           49.000000  6.400000e+01  7.100000e+01  8.200000e+01
# bmi              15.942183  2.324380e+01  2.581663e+01  2.940779e+01
# prs_anemia       -0.000005 -8.506054e-07 -3.152900e-09  8.258885e-07
# prs_ferritin     -0.000007 -1.188703e-06  3.385490e-08  1.281368e-06
# prs_hemoglobin   -0.000016 -3.010211e-06  4.063150e-08  3.106084e-06
# HbPrev1          96.000000  1.330000e+02  1.400000e+02  1.470000e+02
# DaystoPrev1       2.000000  1.020000e+02  1.260000e+02  1.920000e+02
# HbPrev2          86.000000  1.330000e+02  1.400000e+02  1.470000e+02
# DaystoPrev2      96.000000  2.210000e+02  2.800000e+02  3.920000e+02
# HbPrev3                NaN           NaN           NaN           NaN
# DaystoPrev3            NaN           NaN           NaN           NaN
# HbPrev4                NaN           NaN           NaN           NaN
# DaystoPrev4            NaN           NaN           NaN           NaN
# HbPrev5                NaN           NaN           NaN           NaN
# DaystoPrev5            NaN           NaN           NaN           NaN
#
#                     maximum
# age               70.000000
# month             12.000000
# height           198.000000
# weight           172.000000
# bmi               64.776711
# prs_anemia         0.000005
# prs_ferritin       0.000008
# prs_hemoglobin     0.000018
# HbPrev1          187.000000
# DaystoPrev1     1200.000000
# HbPrev2          187.000000
# DaystoPrev2     1552.000000
# HbPrev3                 NaN
# DaystoPrev3             NaN
# HbPrev4                 NaN
# DaystoPrev4             NaN
# HbPrev5                 NaN
# DaystoPrev5             NaN
# Variable year
#     Value    Count  Proportion
# 0  2016.0   3244.0    0.047041
# 1  2017.0  15041.0    0.218109
# 2  2018.0  21625.0    0.313583
# 3  2019.0  22922.0    0.332391
# 4  2020.0   6129.0    0.088876
# Variable smoking
#    Value  Count Proportion
# 0  False  60850   0.882383
# 1   True   8111   0.117617
# Variable snp_17_58358769
#    Value    Count  Proportion
# 0    0.0  67929.0    0.985035
# 1    1.0   1028.0    0.014907
# 2    2.0      4.0    0.000058
# Variable snp_6_32617727
#    Value    Count  Proportion
# 0    1.0  33988.0    0.492858
# 1    0.0  21707.0    0.314772
# 2    2.0  13266.0    0.192370
# Variable snp_15_45095352
#    Value    Count  Proportion
# 0    0.0  60328.0    0.874813
# 1    1.0   8333.0    0.120836
# 2    2.0    300.0    0.004350
# Variable snp_1_169549811
#    Value    Count  Proportion
# 0    0.0  65952.0    0.956367
# 1    1.0   2949.0    0.042763
# 2    2.0     60.0    0.000870
# 3 donations back
# Numerical variables:
#                    minimum            Q1        median            Q3  \
# age              18.000000  3.200000e+01  4.900000e+01  5.800000e+01
# month             1.000000  3.000000e+00  6.000000e+00  1.000000e+01
# height          138.000000  1.620000e+02  1.660000e+02  1.700000e+02
# weight           49.000000  6.400000e+01  7.200000e+01  8.200000e+01
# bmi              15.942183  2.330668e+01  2.586451e+01  2.941176e+01
# prs_anemia       -0.000005 -8.541987e-07 -5.800145e-09  8.252804e-07
# prs_ferritin     -0.000007 -1.185416e-06  3.385490e-08  1.285622e-06
# prs_hemoglobin   -0.000016 -3.001904e-06  4.480680e-08  3.117147e-06
# HbPrev1          96.000000  1.330000e+02  1.400000e+02  1.470000e+02
# DaystoPrev1       2.000000  1.000000e+02  1.240000e+02  1.800000e+02
# HbPrev2          97.000000  1.330000e+02  1.400000e+02  1.470000e+02
# DaystoPrev2      97.000000  2.170000e+02  2.680000e+02  3.650000e+02
# HbPrev3          86.000000  1.330000e+02  1.400000e+02  1.470000e+02
# DaystoPrev3     203.000000  3.380000e+02  4.190000e+02  5.590000e+02
# HbPrev4                NaN           NaN           NaN           NaN
# DaystoPrev4            NaN           NaN           NaN           NaN
# HbPrev5                NaN           NaN           NaN           NaN
# DaystoPrev5            NaN           NaN           NaN           NaN
#
#                     maximum
# age               70.000000
# month             12.000000
# height           197.000000
# weight           172.000000
# bmi               64.776711
# prs_anemia         0.000005
# prs_ferritin       0.000008
# prs_hemoglobin     0.000016
# HbPrev1          187.000000
# DaystoPrev1     1155.000000
# HbPrev2          187.000000
# DaystoPrev2     1342.000000
# HbPrev3          185.000000
# DaystoPrev3     1554.000000
# HbPrev4                 NaN
# DaystoPrev4             NaN
# HbPrev5                 NaN
# DaystoPrev5             NaN
# Variable year
#     Value    Count  Proportion
# 0  2016.0    563.0    0.010219
# 1  2017.0  10278.0    0.186561
# 2  2018.0  17924.0    0.325347
# 3  2019.0  20503.0    0.372159
# 4  2020.0   5824.0    0.105714
# Variable smoking
#    Value  Count Proportion
# 0  False  48750   0.884883
# 1   True   6342   0.115117
# Variable snp_17_58358769
#    Value    Count  Proportion
# 0    0.0  54297.0    0.985570
# 1    1.0    792.0    0.014376
# 2    2.0      3.0    0.000054
# Variable snp_6_32617727
#    Value    Count  Proportion
# 0    1.0  27121.0    0.492286
# 1    0.0  17420.0    0.316198
# 2    2.0  10551.0    0.191516
# Variable snp_15_45095352
#    Value    Count  Proportion
# 0    0.0  48203.0    0.874955
# 1    1.0   6651.0    0.120725
# 2    2.0    238.0    0.004320
# Variable snp_1_169549811
#    Value    Count  Proportion
# 0    0.0  52683.0    0.956273
# 1    1.0   2358.0    0.042801
# 2    2.0     51.0    0.000926
# 4 donations back
# Numerical variables:
#                    minimum            Q1        median            Q3  \
# age              19.000000  3.400000e+01  5.000000e+01  5.900000e+01
# month             1.000000  3.000000e+00  6.000000e+00  1.000000e+01
# height          138.000000  1.620000e+02  1.660000e+02  1.700000e+02
# weight           50.000000  6.400000e+01  7.200000e+01  8.200000e+01
# bmi              15.942183  2.333547e+01  2.591068e+01  2.962963e+01
# prs_anemia       -0.000005 -8.593617e-07 -7.349500e-09  8.235684e-07
# prs_ferritin     -0.000007 -1.182103e-06  3.385490e-08  1.292249e-06
# prs_hemoglobin   -0.000016 -2.989836e-06  5.256755e-08  3.119629e-06
# HbPrev1          96.000000  1.340000e+02  1.400000e+02  1.480000e+02
# DaystoPrev1       2.000000  9.900000e+01  1.190000e+02  1.680000e+02
# HbPrev2          97.000000  1.330000e+02  1.400000e+02  1.470000e+02
# DaystoPrev2      97.000000  2.120000e+02  2.580000e+02  3.440000e+02
# HbPrev3          97.000000  1.330000e+02  1.400000e+02  1.470000e+02
# DaystoPrev3     203.000000  3.310000e+02  3.990000e+02  5.190000e+02
# HbPrev4          86.000000  1.330000e+02  1.400000e+02  1.470000e+02
# DaystoPrev4     304.000000  4.530000e+02  5.470000e+02  7.020000e+02
# HbPrev5                NaN           NaN           NaN           NaN
# DaystoPrev5            NaN           NaN           NaN           NaN
#
#                     maximum
# age               70.000000
# month             12.000000
# height           197.000000
# weight           170.000000
# bmi               64.776711
# prs_anemia         0.000005
# prs_ferritin       0.000008
# prs_hemoglobin     0.000016
# HbPrev1          187.000000
# DaystoPrev1     1027.000000
# HbPrev2          187.000000
# DaystoPrev2     1253.000000
# HbPrev3          185.000000
# DaystoPrev3     1421.000000
# HbPrev4          185.000000
# DaystoPrev4     1546.000000
# HbPrev5                 NaN
# DaystoPrev5             NaN
# Variable year
#     Value    Count  Proportion
# 0  2017.0   5700.0    0.131957
# 1  2018.0  14231.0    0.329452
# 2  2019.0  17894.0    0.414251
# 3  2020.0   5368.0    0.124271
# 4  2016.0      3.0    0.000069
# Variable smoking
#    Value  Count Proportion
# 0  False  38339   0.887559
# 1   True   4857   0.112441
# Variable snp_17_58358769
#    Value    Count  Proportion
# 0    0.0  42597.0    0.986133
# 1    1.0    597.0    0.013821
# 2    2.0      2.0    0.000046
# Variable snp_6_32617727
#    Value    Count  Proportion
# 0    1.0  21216.0    0.491157
# 1    0.0  13735.0    0.317969
# 2    2.0   8245.0    0.190874
# Variable snp_15_45095352
#    Value    Count  Proportion
# 0    0.0  37818.0    0.875498
# 1    1.0   5194.0    0.120243
# 2    2.0    184.0    0.004260
# Variable snp_1_169549811
#    Value    Count  Proportion
# 0    0.0  41300.0    0.956107
# 1    1.0   1854.0    0.042921
# 2    2.0     42.0    0.000972
# 5 donations back
# Numerical variables:
#                    minimum            Q1        median            Q3  \
# age              19.000000  3.600000e+01  5.100000e+01  6.000000e+01
# month             1.000000  3.000000e+00  6.000000e+00  1.000000e+01
# height          138.000000  1.620000e+02  1.660000e+02  1.700000e+02
# weight           50.000000  6.500000e+01  7.200000e+01  8.200000e+01
# bmi              16.302379  2.338435e+01  2.595156e+01  2.970564e+01
# prs_anemia       -0.000005 -8.686403e-07 -8.460900e-09  8.243793e-07
# prs_ferritin     -0.000007 -1.182477e-06  3.198128e-08  1.292132e-06
# prs_hemoglobin   -0.000016 -2.976487e-06  6.106885e-08  3.125541e-06
# HbPrev1          97.000000  1.340000e+02  1.410000e+02  1.480000e+02
# DaystoPrev1       5.000000  9.800000e+01  1.170000e+02  1.577500e+02
# HbPrev2          97.000000  1.340000e+02  1.400000e+02  1.470000e+02
# DaystoPrev2      97.000000  2.100000e+02  2.490000e+02  3.230000e+02
# HbPrev3          97.000000  1.330000e+02  1.400000e+02  1.470000e+02
# DaystoPrev3     203.000000  3.230000e+02  3.840000e+02  4.880000e+02
# HbPrev4          98.000000  1.330000e+02  1.400000e+02  1.470000e+02
# DaystoPrev4     304.000000  4.410000e+02  5.240000e+02  6.530000e+02
# HbPrev5          92.000000  1.330000e+02  1.400000e+02  1.470000e+02
# DaystoPrev5     402.000000  5.610000e+02  6.660000e+02  8.250000e+02
#
#                     maximum
# age               70.000000
# month             12.000000
# height           193.000000
# weight           170.000000
# bmi               64.776711
# prs_anemia         0.000005
# prs_ferritin       0.000008
# prs_hemoglobin     0.000015
# HbPrev1          187.000000
# DaystoPrev1      863.000000
# HbPrev2          187.000000
# DaystoPrev2     1146.000000
# HbPrev3          185.000000
# DaystoPrev3     1240.000000
# HbPrev4          185.000000
# DaystoPrev4     1434.000000
# HbPrev5          183.000000
# DaystoPrev5     1561.000000
# Variable year
#     Value    Count  Proportion
# 0  2017.0   2505.0    0.075456
# 1  2018.0  10646.0    0.320682
# 2  2019.0  15234.0    0.458883
# 3  2020.0   4813.0    0.144979
# Variable smoking
#    Value  Count Proportion
# 0  False  29546   0.889993
# 1   True   3652   0.110007
# Variable snp_17_58358769
#    Value    Count  Proportion
# 0    0.0  32757.0    0.986716
# 1    1.0    440.0    0.013254
# 2    2.0      1.0    0.000030
# Variable snp_6_32617727
#    Value    Count  Proportion
# 0    1.0  16301.0    0.491024
# 1    0.0  10576.0    0.318573
# 2    2.0   6321.0    0.190403
# Variable snp_15_45095352
#    Value    Count  Proportion
# 0    0.0  29065.0    0.875505
# 1    1.0   3994.0    0.120308
# 2    2.0    139.0    0.004187
# Variable snp_1_169549811
#    Value    Count  Proportion
# 0    0.0  31739.0    0.956052
# 1    1.0   1425.0    0.042924
# 2    2.0     34.0    0.001024

# %% [markdown]
# # Scaled based on training data
#
# We need to scale all explanatory variables before doing anything with the SVM. We use the StandardScaler option in the sk-learn package, which makes all variables have a mean of zero and variance of one. We save the scalers for later use when we change time-related variables. Scalers are fitted using only the training data and then used to transform both training and test data.
#
# Test data will be the last year of donations (1 May 2019 - 31 April 2020) and training data everything before that.

# %%
df = pd.read_pickle('../../data/df_2016_2020.pkl')

# %%
var = ['vdonor', 'date', 'sex', 'year', 'age', 'month', 'smoking', 'height', 'weight', 'bmi', 
       'snp_17_58358769', 'snp_6_32617727', 'snp_15_45095352', 'snp_1_169549811', 'prs_anemia', 'prs_ferritin',
       'prs_hemoglobin']
for n in range(1, 6):
    var.extend(['HbPrev'+str(n), 'DaystoPrev'+str(n)])
var.append('Hb_deferral')

df['smoking'] = df['smoking'].astype(int)

train_men = df.loc[(df.sex == 'Men') & (df.date <= '2019-05-01'), var]
train_men = train_men[train_men.columns[4:]]
train_women = df.loc[(df.sex == 'Women') & (df.date <= '2019-05-01'), var]
train_women = train_women[train_women.columns[4:]]

test_men = df.loc[(df.sex == 'Men') & (df.date > '2019-05-01'), var]
test_men = test_men[test_men.columns[4:]]
test_women = df.loc[(df.sex == 'Women') & (df.date > '2019-05-01'), var]
test_women = test_women[test_women.columns[4:]]

# %%
for nback in range(1, 6):
    var = ['age', 'month', 'smoking', 'height', 'weight', 'bmi', 
           'snp_17_58358769', 'snp_6_32617727', 'snp_15_45095352', 'snp_1_169549811', 'prs_anemia', 'prs_ferritin',
           'prs_hemoglobin']
    for n in range(1, nback+1):
        var.extend(['HbPrev'+str(n), 'DaystoPrev'+str(n)])
    var.append('Hb_deferral')
    
    train_men_sub = train_men[var].dropna()
    train_women_sub = train_women[var].dropna()
    test_men_sub = test_men[var].dropna()
    test_women_sub = test_women[var].dropna()
    
    scaler_men = StandardScaler()
    scaler_women = StandardScaler()
    scaler_men.fit(train_men_sub[train_men_sub.columns[:-1]])
    scaler_women.fit(train_women_sub[train_men_sub.columns[:-1]])
    
    train_men_sub[train_men_sub.columns[:-1]] = scaler_men.transform(train_men_sub[train_men_sub.columns[:-1]])
    train_women_sub[train_women_sub.columns[:-1]] = scaler_women.transform(train_women_sub[train_women_sub.columns[:-1]])
    test_men_sub[test_men_sub.columns[:-1]] = scaler_men.transform(test_men_sub[test_men_sub.columns[:-1]])
    test_women_sub[test_women_sub.columns[:-1]] = scaler_women.transform(test_women_sub[test_women_sub.columns[:-1]])
    
    pickle.dump(scaler_men, open('../results/scalers/men_'+str(nback)+'.pkl', 'wb'))
    pickle.dump(scaler_women, open('../results/scalers/women_'+str(nback)+'.pkl', 'wb'))
    
    train_men_sub.to_pickle('../../data/scaled/men_'+str(nback)+'_train.pkl')
    train_women_sub.to_pickle('../../data/scaled/women_'+str(nback)+'_train.pkl')
    test_men_sub.to_pickle('../../data/scaled/men_'+str(nback)+'_test.pkl')
    test_women_sub.to_pickle('../../data/scaled/women_'+str(nback)+'_test.pkl')

# %% [markdown]
# # Limited variables ('onlyhb'), scaled on training data
# To draw comparisons with results on the Dutch data, we also fit the model on data only containing the variables present in the Dutch data. This has the same result as removing those variables from the scaled data created above.

# %%
df = pd.read_pickle('../../data/df_2016_2020.pkl')

# %%
var = ['vdonor', 'date', 'sex', 'year', 'age', 'month']
for n in range(1, 6):
    var.extend(['HbPrev'+str(n), 'DaystoPrev'+str(n)])
var.append('Hb_deferral')

train_men = df.loc[(df.sex == 'Men') & (df.date <= '2019-05-01'), var]
train_men = train_men[train_men.columns[4:]]
train_women = df.loc[(df.sex == 'Women') & (df.date <= '2019-05-01'), var]
train_women = train_women[train_women.columns[4:]]

test_men = df.loc[(df.sex == 'Men') & (df.date > '2019-05-01'), var]
test_men = test_men[test_men.columns[4:]]
test_women = df.loc[(df.sex == 'Women') & (df.date > '2019-05-01'), var]
test_women = test_women[test_women.columns[4:]]

# %%
for nback in range(1, 6):
    var = ['age', 'month']
    for n in range(1, nback+1):
        var.extend(['HbPrev'+str(n), 'DaystoPrev'+str(n)])
    var.append('Hb_deferral')
    
    train_men_sub = train_men[var].dropna()
    train_women_sub = train_women[var].dropna()
    test_men_sub = test_men[var].dropna()
    test_women_sub = test_women[var].dropna()
    
    scaler_men = StandardScaler()
    scaler_women = StandardScaler()
    scaler_men.fit(train_men_sub[train_men_sub.columns[:-1]])
    scaler_women.fit(train_women_sub[train_men_sub.columns[:-1]])
    
    pickle.dump(scaler_men, open('../results/scalers_onlyhb/men_'+str(nback)+'.pkl', 'wb'))
    pickle.dump(scaler_women, open('../results/scalers_onlyhb/women_'+str(nback)+'.pkl', 'wb'))
    
    train_men_sub[train_men_sub.columns[:-1]] = scaler_men.transform(train_men_sub[train_men_sub.columns[:-1]])
    train_women_sub[train_women_sub.columns[:-1]] = scaler_women.transform(train_women_sub[train_women_sub.columns[:-1]])
    test_men_sub[test_men_sub.columns[:-1]] = scaler_men.transform(test_men_sub[test_men_sub.columns[:-1]])
    test_women_sub[test_women_sub.columns[:-1]] = scaler_women.transform(test_women_sub[test_women_sub.columns[:-1]])
    
    train_men_sub.to_pickle('../../data/scaled_onlyhb/men_'+str(nback)+'_train.pkl')
    train_women_sub.to_pickle('../../data/scaled_onlyhb/women_'+str(nback)+'_train.pkl')
    test_men_sub.to_pickle('../../data/scaled_onlyhb/men_'+str(nback)+'_test.pkl')
    test_women_sub.to_pickle('../../data/scaled_onlyhb/women_'+str(nback)+'_test.pkl')

# %% [markdown]
# # Another run with only Hb + genetic data
# This excludes weight, height, bmi and smoking. This allows us to see the relative added value of genetic data only.

# %%
df = pd.read_pickle('../../data/df_2016_2020.pkl')
df.head()
# Out:
#           vdonor  age    sex       date     Hb  Hb_deferral  height  weight  \
# 49  MV4ALL7LH8X3   52  Women 2016-03-31  131.0            0     163      79
# 50  MV4ALL7LH8X3   52  Women 2016-07-05  118.0            1     163      79
# 51  MV4ALL7LH8X3   52  Women 2016-10-06  125.0            0     163      79
# 52  MV4ALL7LH8X3   53  Women 2016-12-30  121.0            1     163      79
# 53  MV4ALL7LH8X3   53  Women 2017-03-23  138.0            0     163      79
#
#     smoking      bmi  snp_17_58358769  snp_6_32617727  snp_15_45095352  \
# 49    False  29.7339                0               1                0
# 50    False  29.7339                0               1                0
# 51    False  29.7339                0               1                0
# 52    False  29.7339                0               1                0
# 53    False  29.7339                0               1                0
#
#     snp_1_169549811  prs_anemia  prs_ferritin  prs_hemoglobin  year  month  \
# 49                0    0.000001 -1.510828e-08       -0.000002  2016      3
# 50                0    0.000001 -1.510828e-08       -0.000002  2016      7
# 51                0    0.000001 -1.510828e-08       -0.000002  2016     10
# 52                0    0.000001 -1.510828e-08       -0.000002  2016     12
# 53                0    0.000001 -1.510828e-08       -0.000002  2017      3
#
#     HbPrev1  DaystoPrev1  HbPrev2  DaystoPrev2  HbPrev3  DaystoPrev3  HbPrev4  \
# 49      NaN          NaN      NaN          NaN      NaN          NaN      NaN
# 50    131.0         96.0      NaN          NaN      NaN          NaN      NaN
# 51    118.0         93.0    131.0        189.0      NaN          NaN      NaN
# 52    125.0         85.0    118.0        178.0    131.0        274.0      NaN
# 53    121.0         83.0    125.0        168.0    118.0        261.0    131.0
#
#     DaystoPrev4  HbPrev5  DaystoPrev5
# 49          NaN      NaN          NaN
# 50          NaN      NaN          NaN
# 51          NaN      NaN          NaN
# 52          NaN      NaN          NaN
# 53        357.0      NaN          NaN

# %%
var = ['vdonor', 'date', 'sex', 'year', 'age', 'month', 'snp_17_58358769', 'snp_6_32617727',  
       'snp_15_45095352', 'snp_1_169549811', 'prs_anemia', 'prs_ferritin', 'prs_hemoglobin']
for n in range(1, 6):
    var.extend(['HbPrev'+str(n), 'DaystoPrev'+str(n)])
var.append('Hb_deferral')

train_men = df.loc[(df.sex == 'Men') & (df.date <= '2019-05-01'), var]
train_men = train_men[train_men.columns[4:]]
train_women = df.loc[(df.sex == 'Women') & (df.date <= '2019-05-01'), var]
train_women = train_women[train_women.columns[4:]]

test_men = df.loc[(df.sex == 'Men') & (df.date > '2019-05-01'), var]
test_men = test_men[test_men.columns[4:]]
test_women = df.loc[(df.sex == 'Women') & (df.date > '2019-05-01'), var]
test_women = test_women[test_women.columns[4:]]

# %%
for nback in range(1, 6):
    var = ['age', 'month', 'snp_17_58358769', 'snp_6_32617727', 'snp_15_45095352', 
           'snp_1_169549811', 'prs_anemia', 'prs_ferritin', 'prs_hemoglobin']
    for n in range(1, nback+1):
        var.extend(['HbPrev'+str(n), 'DaystoPrev'+str(n)])
    var.append('Hb_deferral')
    
    train_men_sub = train_men[var].dropna()
    train_women_sub = train_women[var].dropna()
    test_men_sub = test_men[var].dropna()
    test_women_sub = test_women[var].dropna()
    
    scaler_men = StandardScaler()
    scaler_women = StandardScaler()
    scaler_men.fit(train_men_sub[train_men_sub.columns[:-1]])
    scaler_women.fit(train_women_sub[train_men_sub.columns[:-1]])
    
    pickle.dump(scaler_men, open('../results/scalers_hbgen/men_'+str(nback)+'.pkl', 'wb'))
    pickle.dump(scaler_women, open('../results/scalers_hbgen/women_'+str(nback)+'.pkl', 'wb'))
    
    train_men_sub[train_men_sub.columns[:-1]] = scaler_men.transform(train_men_sub[train_men_sub.columns[:-1]])
    train_women_sub[train_women_sub.columns[:-1]] = scaler_women.transform(train_women_sub[train_women_sub.columns[:-1]])
    test_men_sub[test_men_sub.columns[:-1]] = scaler_men.transform(test_men_sub[test_men_sub.columns[:-1]])
    test_women_sub[test_women_sub.columns[:-1]] = scaler_women.transform(test_women_sub[test_women_sub.columns[:-1]])
    
    train_men_sub.to_pickle('../../data/scaled_hbgen/men_'+str(nback)+'_train.pkl')
    train_women_sub.to_pickle('../../data/scaled_hbgen/women_'+str(nback)+'_train.pkl')
    test_men_sub.to_pickle('../../data/scaled_hbgen/men_'+str(nback)+'_test.pkl')
    test_women_sub.to_pickle('../../data/scaled_hbgen/women_'+str(nback)+'_test.pkl')
